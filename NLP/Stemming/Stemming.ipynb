# %% [markdown]
# <a href="https://colab.research.google.com/github/AyushGupta510/GenAI---Learning/blob/main/NLP/Stemming/Stemming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Classification Problem
## Comments of product is a positive review or negative review
## Reviews ----> eating , eat , eaten - eat
words = ["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %% [markdown]
# PorterStemmer

# %%
from nltk.stem import PorterStemmer

# %%
stemming=PorterStemmer()

# %%
for word in words:
  print(word+"--->"+stemming.stem(word))
# Out:
# eating--->eat
# eats--->eat
# eaten--->eaten
# writing--->write
# writes--->write
# programming--->program
# programs--->program
# history--->histori
# finally--->final
# finalized--->final

# %%
stemming.stem("sitting")
# Out:
# 'sit'

# %% [markdown]
# RegexpStemmer class

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer=RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
reg_stemmer.stem("eating")
# Out:
# 'eat'

# %%
reg_stemmer.stem("ingeating")
# Out:
# 'ingeat'

# %% [markdown]
# Snowball Stemmer

# %%
from nltk.stem import SnowballStemmer

# %%
snowballsstemmer = SnowballStemmer('english')

# %%
for word in words:
  print(word+"--->"+snowballsstemmer.stem(word))
# Out:
# eating--->eat
# eats--->eat
# eaten--->eaten
# writing--->write
# writes--->write
# programming--->program
# programs--->program
# history--->histori
# finally--->final
# finalized--->final

# %%
stemming.stem("fairly"),stemming.stem("sportingly")
# Out:
# ('fairli', 'sportingli')

# %%
snowballsstemmer.stem("fairly"),snowballsstemmer.stem("sportingly")
# Out:
# ('fair', 'sport')

# %%
# disadvantage --->
stemming.stem('goes')
# Out:
# 'goe'
