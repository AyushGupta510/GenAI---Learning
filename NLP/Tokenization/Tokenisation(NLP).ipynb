# %% [markdown]
# <a href="https://colab.research.google.com/github/AyushGupta510/GenAI---Learning/blob/main/NLP/Tokenization/Tokenisation(NLP).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
corpus="""Hello Welcome , to NLP learning stage , My name is Ayush!
and today I would learn about NLP (tokenisation) by implementing it.
"""

# %%
print(corpus)
# Out:
# Hello Welcome , to NLP learning stage , My name is Ayush!
# and today I would learn about NLP (tokenisation) by implementing it.

# %%
## Tokenisation
## Paragraph --> Sentences
from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
documents = sent_tokenize(corpus)

# %%
documents
# Out:
# ['Hello Welcome , to NLP learning stage , My name is Ayush!',
#  'and today I would learn about NLP (tokenisation) by implementing it.']

# %%
## Tokenization
## paragraph --> Words
## sentence ---> Words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'NLP',
#  'learning',
#  'stage',
#  ',',
#  'My',
#  'name',
#  'is',
#  'Ayush',
#  '!',
#  'and',
#  'today',
#  'I',
#  'would',
#  'learn',
#  'about',
#  'NLP',
#  '(',
#  'tokenisation',
#  ')',
#  'by',
#  'implementing',
#  'it',
#  '.']

# %%
for sentence in documents:
  print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'NLP', 'learning', 'stage', ',', 'My', 'name', 'is', 'Ayush', '!']
# ['and', 'today', 'I', 'would', 'learn', 'about', 'NLP', '(', 'tokenisation', ')', 'by', 'implementing', 'it', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'NLP',
#  'learning',
#  'stage',
#  ',',
#  'My',
#  'name',
#  'is',
#  'Ayush',
#  '!',
#  'and',
#  'today',
#  'I',
#  'would',
#  'learn',
#  'about',
#  'NLP',
#  '(',
#  'tokenisation',
#  ')',
#  'by',
#  'implementing',
#  'it',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'NLP',
#  'learning',
#  'stage',
#  ',',
#  'My',
#  'name',
#  'is',
#  'Ayush',
#  '!',
#  'and',
#  'today',
#  'I',
#  'would',
#  'learn',
#  'about',
#  'NLP',
#  '(',
#  'tokenisation',
#  ')',
#  'by',
#  'implementing',
#  'it',
#  '.']
